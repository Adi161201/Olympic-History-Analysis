# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/120-years-of-olympic-history-athletes-and-results/noc_regions.csv
# /kaggle/input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv

# %% [markdown]
# Content
#
# The file athlete_events.csv contains 271116 rows and 15 columns; Each row corresponds to an individual athlete competing in an individual Olympic event (athlete-events). The columns are the following:
#
# * ID - Unique number for each athlete;
# * Name - Athlete's name;
# * Sex - M or F;
# * Age - Integer;
# * Height - In centimeters;
# * Weight - In kilograms;
# * Team - Team name;
# * NOC - National Olympic Committee 3-letter code;
# * Games - Year and season;
# * Year - Integer;
# * Season - Summer or Winter;
# * City - Host city;
# * Sport - Sport;
# * Event - Event;
# * Medal - Gold, Silver, Bronze, or NA.

# %% [markdown]
# ## 1. Importing Modules

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Importing Data

# %%
df_athlete_events = pd.read_csv('/kaggle/input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv',index_col=0)
df_regions = pd.read_csv('/kaggle/input/120-years-of-olympic-history-athletes-and-results/noc_regions.csv')

# %%
df_athlete_events.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
df_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# import sqlalchemy and create a sqlite engine
from sqlalchemy import create_engine, text
engine = create_engine('sqlite://', echo=False)
con=engine.connect()

# export the dataframe as a table 'athlete_events' to the sqlite engine
df_athlete_events.to_sql("athlete_events", con)
df_regions.to_sql("regions", con)
# Out:
# 230

# %%
def run_query(a):
    df_sql = pd.read_sql_query(text(a),con,index_col = None)
    return df_sql

# %% [markdown]
# ## 3. Reviewing data

# %%
run_query("Select * from athlete_events")
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
run_query("Select * from regions")
# Out:
#      index  NOC       region                 notes
# 0        0  AFG  Afghanistan                  None
# 1        1  AHO      Curacao  Netherlands Antilles
# 2        2  ALB      Albania                  None
# 3        3  ALG      Algeria                  None
# 4        4  AND      Andorra                  None
# ..     ...  ...          ...                   ...
# 225    225  YEM        Yemen                  None
# 226    226  YMD        Yemen           South Yemen
# 227    227  YUG       Serbia            Yugoslavia
# 228    228  ZAM       Zambia                  None
# 229    229  ZIM     Zimbabwe                  None
#
# [230 rows x 4 columns]

# %%
df_athlete_events.describe()
# Out:
#                  Age         Height         Weight           Year
# count  261642.000000  210945.000000  208241.000000  271116.000000
# mean       25.556898     175.338970      70.702393    1978.378480
# std         6.393561      10.518462      14.348020      29.877632
# min        10.000000     127.000000      25.000000    1896.000000
# 25%        21.000000     168.000000      60.000000    1960.000000
# 50%        24.000000     175.000000      70.000000    1988.000000
# 75%        28.000000     183.000000      79.000000    2002.000000
# max        97.000000     226.000000     214.000000    2016.000000

# %%
df_athlete_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 1 to 135571
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    271116 non-null  object
#  1   Sex     271116 non-null  object
#  2   Age     261642 non-null  float64
#  3   Height  210945 non-null  float64
#  4   Weight  208241 non-null  float64
#  5   Team    271116 non-null  object
#  6   NOC     271116 non-null  object
#  7   Games   271116 non-null  object
#  8   Year    271116 non-null  int64
#  9   Season  271116 non-null  object
#  10  City    271116 non-null  object
#  11  Sport   271116 non-null  object
#  12  Event   271116 non-null  object
#  13  Medal   39783 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# ## 4. Joining Dataframes

# %%
joining= """
Select a.*,r.region,r.notes
from athlete_events as a
Left join regions as 'r'
on a.NOC=r.NOC ;
"""
df = run_query(joining)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball  None        China  None
# ...

# %%
df.to_sql("df", con)
# Out:
# 271116

# %% [markdown]
# ## 5. Distribution of Age of Gold medalist

# %%
query = """
Select a.*
from df as a
where a.Medal="Gold";
"""
goldmedal = run_query(query)
goldmedal.head()
# Out:
#    index  ID                     Name Sex   Age  Height  Weight  \
# 0      3   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 1     42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 2     44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 3     48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 4     60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0
#
#              Team  NOC        Games  Year  Season         City          Sport  \
# 0  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 1         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 2         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 3         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 4          Norway  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                               Event Medal   region notes
# ...

# %% [markdown]
# We will plot the age distribution which are Not NULL.

# %%
goldmedal['Age'].isna().sum()
# Out:
# 148

# %%
goldmedal = goldmedal[np.isfinite(goldmedal['Age'])]

# %%
goldmedal['Age'].isna().sum()
# Out:
# 0

# %%
goldmedal
# Out:
#         index      ID                                 Name Sex   Age  Height  \
# 0           3       4                 Edgar Lindenau Aabye   M  34.0     NaN
# 1          42      17              Paavo Johannes Aaltonen   M  28.0   175.0
# 2          44      17              Paavo Johannes Aaltonen   M  28.0   175.0
# 3          48      17              Paavo Johannes Aaltonen   M  28.0   175.0
# 4          60      20                   Kjetil Andr Aamodt   M  20.0   176.0
# ...       ...     ...                                  ...  ..   ...     ...
# 13367  270981  135503                      Zurab Zviadauri   M  23.0   182.0
# 13368  271009  135520                          Julia Zwehl   F  28.0   167.0
# 13369  271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0
# 13370  271049  135545                      Henk Jan Zwolle   M  31.0   197.0
# 13371  271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0
#
# ...

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='Age',data=df)
plt.title('Distribution of Gold Medals')
plt.xticks(rotation=90,size=11)
plt.yticks(size=11)
plt.tight_layout()

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='Age',data=df,hue='Sex')
plt.title('Distribution of Gold Medals')
plt.xticks(rotation=90,size=11)
plt.yticks(size=11)
plt.tight_layout()

# %% [markdown]
# * People with highest number of gold medals are of Age 23.
# * There are few people who have gold medal and also Age >50

# %%
goldmedal.to_sql("goldmedal", con)
# Out:
# 13224

# %%
query="""
Select Count(Age)
from goldmedal
where goldmedal.Age>50;
"""
run_query(query)
# Out:
#    Count(Age)
# 0          65

# %% [markdown]
# We will make another dataframe to see the sports in which people above Age 50 have received Gold Medal.

# %%
query="""
Select Sport , Age
from goldmedal
where Age>50;
"""
master_goldmedal = run_query(query)

# %%
master_goldmedal
# Out:
#                Sport   Age
# 0      Equestrianism  54.0
# 1            Sailing  56.0
# 2      Equestrianism  52.0
# 3      Equestrianism  56.0
# 4      Equestrianism  52.0
# ..               ...   ...
# 60           Archery  63.0
# 61          Shooting  56.0
# 62  Art Competitions  60.0
# 63           Archery  58.0
# 64  Art Competitions  54.0
#
# [65 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Sport',data=master_goldmedal)
plt.title('Distribution of Gold Medals Above Age 50 ')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# ## 6. Women in Athletics

# %% [markdown]
# Studying the data we can try to understand how much medals we have only for women in the recent history of the Summer Games.

# %%
query= """
Select * from df
where df.Sex='F' and df.Season="Summer";
"""
women_df = run_query(query)

# %%
women_df
# Out:
#         index      ID                                 Name Sex   Age  Height  \
# 0          26       8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0
# 1          27       8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0
# 2          32      13                   Minna Maarit Aalto   F  30.0   159.0
# 3          33      13                   Minna Maarit Aalto   F  34.0   159.0
# 4          79      21            Ragnhild Margrethe Aamodt   F  27.0   163.0
# ...       ...     ...                                  ...  ..   ...     ...
# 59438  271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0
# 59439  271099  135560                    Stavroula Zygouri   F  36.0   171.0
# 59440  271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0
# 59441  271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0
# 59442  271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0
#
# ...

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='Year',data=women_df)
plt.title('Year wise Distribution of Medals to women')
plt.xticks(rotation=90,size=11)
plt.tight_layout()

# %% [markdown]
# ## 7. Medals per Country

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball  None        China  None
# ...

# %% [markdown]
# Top 5 Gold Medal Countries

# %%
goldmedal.head()
# Out:
#    index  ID                     Name Sex   Age  Height  Weight  \
# 0      3   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 1     42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 2     44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 3     48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 4     60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0
#
#              Team  NOC        Games  Year  Season         City          Sport  \
# 0  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 1         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 2         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 3         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 4          Norway  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                               Event Medal   region notes
# ...

# %%
query = """
Select region , Count(region) as 'Medals'
from goldmedal
group by region
order by Count(region) DESC
LIMIT 5;
"""
total_gold_medals = run_query(query)
total_gold_medals
# Out:
#     region  Medals
# 0      USA    2627
# 1   Russia    1599
# 2  Germany    1293
# 3       UK     657
# 4    Italy     567

# %%
g = sns.catplot(x="region", y="Medals", data=total_gold_medals,
                height=5, kind="bar", palette="muted")
g.despine(left=True)
g.set_xlabels("Top 5 countries")
g.set_ylabels("Number of Medals")
plt.title('Medals per Country')
plt.show()

# %% [markdown]
# The USA seems to be the most winning country.

# %% [markdown]
# ## 8. Disciplines with the greatest number of Gold Medals

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball  None        China  None
# ...

# %%
query="""
Select * from goldmedal;
"""
run_query(query)
# Out:
#        level_0   index      ID                                 Name Sex   Age  \
# 0            0       3       4                 Edgar Lindenau Aabye   M  34.0
# 1            1      42      17              Paavo Johannes Aaltonen   M  28.0
# 2            2      44      17              Paavo Johannes Aaltonen   M  28.0
# 3            3      48      17              Paavo Johannes Aaltonen   M  28.0
# 4            4      60      20                   Kjetil Andr Aamodt   M  20.0
# ...        ...     ...     ...                                  ...  ..   ...
# 13219    13367  270981  135503                      Zurab Zviadauri   M  23.0
# 13220    13368  271009  135520                          Julia Zwehl   F  28.0
# 13221    13369  271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0
# 13222    13370  271049  135545                      Henk Jan Zwolle   M  31.0
# 13223    13371  271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0
#
# ...

# %%
query = """
Select Event , Count(Medal) as 'Medals'
from goldmedal
group by Event
order by Count(Medal) DESC
LIMIT 15;
"""
event_gold_medal = run_query(query)
event_gold_medal
# Out:
#                                               Event  Medals
# 0                           Football Men's Football     409
# 1                       Ice Hockey Men's Ice Hockey     407
# 2                               Hockey Men's Hockey     347
# 3                       Water Polo Men's Water Polo     283
# 4                  Gymnastics Men's Team All-Around     249
# 5                         Rowing Men's Coxed Eights     243
# 6                       Basketball Men's Basketball     234
# 7                           Handball Men's Handball     194
# 8                       Volleyball Men's Volleyball     166
# 9                             Hockey Women's Hockey     158
# 10                    Volleyball Women's Volleyball     156
# 11                        Handball Women's Handball     155
# 12    Swimming Men's 4 x 200 metres Freestyle Relay     151
# 13                         Fencing Men's epee, Team     133
# 14  Swimming Women's 4 x 100 metres Freestyle Relay     131

# %%
plt.figure(figsize=(12,5))
ax = sns.barplot(x='Event',y='Medals',data = event_gold_medal)

plt.xticks(rotation=90)
# g.set_xlabels("Top 15 countries")
# g.set_ylabels("Number of Gold Medals")
plt.title('Medals per top 15 Event')
plt.show()

# %% [markdown]
# ## 9. Median Height/Weight of an Olympic medalist

# %% [markdown]
# Let's try to plot a scatterplot of height vs weight to see the distribution of values (without grouping by discipline).
#
# First of all, we have to take again the goldMedals dataframe

# %%
goldmedal.head()
# Out:
#    index  ID                     Name Sex   Age  Height  Weight  \
# 0      3   4     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 1     42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 2     44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 3     48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 4     60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0
#
#              Team  NOC        Games  Year  Season         City          Sport  \
# 0  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 1         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 2         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 3         Finland  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 4          Norway  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                               Event Medal   region notes
# ...

# %%
goldmedal.isna().sum()
# Out:
# index         0
# ID            0
# Name          0
# Sex           0
# Age           0
# Height     2692
# Weight     2976
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# region        1
# notes     13053
# dtype: int64

# %%
query="""
Select * from goldmedal
where Height is NOT NULL and Weight is NOT NULL;
"""
notnullmedals = run_query(query)
notnullmedals
# Out:
#        level_0   index      ID                                 Name Sex   Age  \
# 0            1      42      17              Paavo Johannes Aaltonen   M  28.0
# 1            2      44      17              Paavo Johannes Aaltonen   M  28.0
# 2            3      48      17              Paavo Johannes Aaltonen   M  28.0
# 3            4      60      20                   Kjetil Andr Aamodt   M  20.0
# 4            5      73      20                   Kjetil Andr Aamodt   M  30.0
# ...        ...     ...     ...                                  ...  ..   ...
# 10162    13367  270981  135503                      Zurab Zviadauri   M  23.0
# 10163    13368  271009  135520                          Julia Zwehl   F  28.0
# 10164    13369  271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0
# 10165    13370  271049  135545                      Henk Jan Zwolle   M  31.0
# 10166    13371  271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0
#
# ...

# %%
plt.figure(figsize=(7, 5))
ax = sns.scatterplot(x="Height", y="Weight", data=notnullmedals, hue='Sex')
plt.title('Height vs Weight of Olympic Medalists')
plt.show()

# %% [markdown]
# The vast majority of the samples show a linear relation between height and weight (the more the weight, the more the height).

# %% [markdown]
# ## 10. In which Sport/event, India has won highest medals.

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball  None        China  None
# ...

# %%
df[df['Medal'].isna()]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 0             China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df[ (df['region']=='India') & ~(df['Medal']=="None")]
# Out:
#             ID                                           Name Sex   Age  \
# 505        281                                 S. Abdul Hamid   M   NaN
# 506        281                                 S. Abdul Hamid   M   NaN
# 895        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 896        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 897        512                Shiny Kurisingal Abraham-Wilson   F  23.0
# ...        ...                                            ...  ..   ...
# 264139  132177                           Mohammad Anas Yahiya   M  21.0
# 265876  133029  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0
# 266934  133554                           Sayed Muhammad Yusuf   M   NaN
# 270912  135480                                   Geeta Zutshi   F  23.0
# 270913  135480                                   Geeta Zutshi   F  27.0
#
#         Height  Weight   Team  NOC        Games  Year  Season            City  \
# ...

# %%
query="""
Select Sport,Count(Medal) as 'Medals'
from df
where region='India' and Medal<>'NA'
ORDER BY Count(Medal) DESC
LIMIT 5;
"""
india_sports = run_query(query)
india_sports
# Out:
#     Sport  Medals
# 0  Hockey     197
